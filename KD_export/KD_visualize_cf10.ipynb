# %%
from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
from kd_export_cf10 import train_light_ce, test_light_ce, train_light_ce_and_kd, test_light_ce_and_kd
# Out:
# ######################################################################
# Loading CIFAR-10 dataset:
# Files already downloaded and verified
# Files already downloaded and verified
# Number of training samples: 40000
# Number of validation samples: 10000
# Number of testing samples: 10000
#
# ######################################################################
# Instantiate the teacher model.
# Cross-entropy runs with teacher model:
# Epoch 1/10, Training Loss: 1.5087161141395569
# Epoch 1/10, Validation Loss: 1.2298
# Epoch 2/10, Training Loss: 1.1166450530052185
# Epoch 2/10, Validation Loss: 1.0282
# Epoch 3/10, Training Loss: 0.9739252459287644
# Epoch 3/10, Validation Loss: 0.9894
# Epoch 4/10, Training Loss: 0.8837763190984725
# Epoch 4/10, Validation Loss: 0.9587
# Epoch 5/10, Training Loss: 0.816731366944313
# Epoch 5/10, Validation Loss: 0.9620
# Epoch 6/10, Training Loss: 0.7674031199932099
# Epoch 6/10, Validation Loss: 0.9313
# Epoch 7/10, Training Loss: 0.7184122700572014
# Epoch 7/10, Validation Loss: 0.9393
# Epoch 8/10, Training Loss: 0.6817465553760529
# Epoch 8/10, Validation Loss: 0.9420
# Epoch 9/10, Training Loss: 0.6509072054386139
# Epoch 9/10, Validation Loss: 1.0018
# Epoch 10/10, Training Loss: 0.6219546229481697
# Epoch 10/10, Validation Loss: 0.9183
# Teacher Accuracy: 73.38%
# Instantiate the student model.
# Instantiate a copy of the student model.
#
# ######################################################################
# Cross-entropy runs with student model:
# Epoch 1/10, Training Loss: 1.5100280024528503
# Epoch 1/10, Validation Loss: 1.3231
# Epoch 2/10, Training Loss: 1.2263155747890473
# Epoch 2/10, Validation Loss: 1.2239
# Epoch 3/10, Training Loss: 1.104692109775543
# Epoch 3/10, Validation Loss: 1.1251
# Epoch 4/10, Training Loss: 1.0297809232711792
# Epoch 4/10, Validation Loss: 1.0944
# Epoch 5/10, Training Loss: 0.9680679662704468
# Epoch 5/10, Validation Loss: 1.0685
# Epoch 6/10, Training Loss: 0.9147407596111298
# Epoch 6/10, Validation Loss: 1.0671
# Epoch 7/10, Training Loss: 0.8752483759880066
# Epoch 7/10, Validation Loss: 1.0754
# Epoch 8/10, Training Loss: 0.835044296836853
# Epoch 8/10, Validation Loss: 1.0345
# Epoch 9/10, Training Loss: 0.799290370297432
# Epoch 9/10, Validation Loss: 1.0351
# Epoch 10/10, Training Loss: 0.762256669139862
# Epoch 10/10, Validation Loss: 1.0661
# Student Accuracy: 68.80%
#
# ######################################################################
# Knowledge Distillation runs with the copy of the student model:
# Epoch 1/10, Training Loss: 1.7110176126003265
# Epoch 1/10, Validation Loss: 1.2904
# Epoch 2/10, Training Loss: 1.2974525785923003
# Epoch 2/10, Validation Loss: 1.1807
# Epoch 3/10, Training Loss: 1.1370783059120178
# Epoch 3/10, Validation Loss: 1.1138
# Epoch 4/10, Training Loss: 1.0429515448570252
# Epoch 4/10, Validation Loss: 1.0638
# Epoch 5/10, Training Loss: 0.9652231157064438
# Epoch 5/10, Validation Loss: 1.0494
# Epoch 6/10, Training Loss: 0.9189511641979218
# Epoch 6/10, Validation Loss: 1.0252
# Epoch 7/10, Training Loss: 0.8785683857917785
# Epoch 7/10, Validation Loss: 1.0182
# Epoch 8/10, Training Loss: 0.8446410458087921
# Epoch 8/10, Validation Loss: 1.0184
# Epoch 9/10, Training Loss: 0.8136943791151047
# Epoch 9/10, Validation Loss: 0.9770
# Epoch 10/10, Training Loss: 0.7930495169878006
# Epoch 10/10, Validation Loss: 0.9705
# -----------------------------------------
# Student accuracy with CE + KD:
# Accuracy: 70.40%
# Precision: 0.71
# Recall: 0.70
# F1 Score: 0.70
# Model saved as teacher_model_cf10.pth, student_model_cf10.pth and student_model_KD_cf10.pth

# %% [markdown]
# Knowledge distillation run
# --------------------------

# %%
test_accuracy_light_ce = test_light_ce[1]["accuracy"] * 100
test_accuracy_light_ce_and_kd = test_light_ce_and_kd[1]["accuracy"] * 100

plt.suptitle("Training and Validation Loss of Student model", fontsize=16)

# Visualize the loss scores of student model - ce
plt.figure(figsize=(12, 10))
plt.subplot(1, 2, 1)
plt.plot(range(1, 11), train_light_ce[0], label="Train Loss")
plt.plot(range(1, 11), train_light_ce[1], label="Validation Loss")
# plt.axhline(y=test_accuracy_light_ce, color='red', linestyle='--', label='Test Accuracy')
plt.legend(loc='upper right')
plt.title('with Cross-Entropy')

# Visualize the loss scores of student model - ce + kd
plt.subplot(1, 2, 2)
plt.plot(range(1, 11), train_light_ce_and_kd[0], label="Train Loss")
plt.plot(range(1, 11), train_light_ce_and_kd[1], label="Validation Loss")
# plt.axhline(y=test_accuracy_light_ce_and_kd, color='red', linestyle='--', label='Test Accuracy')
plt.legend(loc='upper right')
plt.title('with Knowledge Distillation')
plt.show()

# %%
# Generate the confusion matrix
cm = test_light_ce_and_kd[0]
# Visualize the confusion matrix
plt.figure(figsize=(8, 6))
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix of Student model with Knowledge Distillation")
plt.show()
