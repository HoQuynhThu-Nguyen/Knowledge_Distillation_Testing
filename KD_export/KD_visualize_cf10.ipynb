# %%
from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
from kd_export_cf10 import train_light_ce, test_light_ce, train_light_ce_and_kd, test_light_ce_and_kd
# Out:
# ######################################################################
# Loading CIFAR-10 dataset:
# Files already downloaded and verified
# Files already downloaded and verified
# Number of training samples: 40000
# Number of validation samples: 10000
# Number of testing samples: 10000
#
# ######################################################################
# Instantiate the teacher model.
# Cross-entropy runs with teacher model:
# Epoch 1/10, Training Loss: 1.5964266384124757
# Epoch 1/10, Validation Loss: 1.3311
# Epoch 2/10, Training Loss: 1.2064807410717011
# Epoch 2/10, Validation Loss: 1.1391
# Epoch 3/10, Training Loss: 1.0347936308383943
# Epoch 3/10, Validation Loss: 1.0450
# Epoch 4/10, Training Loss: 0.9380762628316879
# Epoch 4/10, Validation Loss: 0.9987
# Epoch 5/10, Training Loss: 0.8643596223592758
# Epoch 5/10, Validation Loss: 0.9701
# Epoch 6/10, Training Loss: 0.815324884390831
# Epoch 6/10, Validation Loss: 0.9796
# Epoch 7/10, Training Loss: 0.7745495794773102
# Epoch 7/10, Validation Loss: 0.9452
# Epoch 8/10, Training Loss: 0.7295416473388672
# Epoch 8/10, Validation Loss: 1.0166
# Epoch 9/10, Training Loss: 0.7013058530569076
# Epoch 9/10, Validation Loss: 0.9976
# Epoch 10/10, Training Loss: 0.668480921626091
# Epoch 10/10, Validation Loss: 0.9899
# Teacher Accuracy: 70.82%
# Instantiate the student model.
# Instantiate a copy of the student model.
#
# ######################################################################
# Cross-entropy runs with student model:
# Epoch 1/10, Training Loss: 1.532205939912796
# Epoch 1/10, Validation Loss: 1.3206
# Epoch 2/10, Training Loss: 1.2279994580745697
# Epoch 2/10, Validation Loss: 1.1829
# Epoch 3/10, Training Loss: 1.108036671257019
# Epoch 3/10, Validation Loss: 1.1249
# Epoch 4/10, Training Loss: 1.0263731246948242
# Epoch 4/10, Validation Loss: 1.1111
# Epoch 5/10, Training Loss: 0.9635102575540543
# Epoch 5/10, Validation Loss: 1.0557
# Epoch 6/10, Training Loss: 0.9148921213150024
# Epoch 6/10, Validation Loss: 1.0530
# Epoch 7/10, Training Loss: 0.8739592032194138
# Epoch 7/10, Validation Loss: 1.0912
# Epoch 8/10, Training Loss: 0.8395613568782806
# Epoch 8/10, Validation Loss: 1.0654
# Epoch 9/10, Training Loss: 0.8074837692975998
# Epoch 9/10, Validation Loss: 1.0715
# Epoch 10/10, Training Loss: 0.7770848660230637
# Epoch 10/10, Validation Loss: 1.0725
# Student Accuracy: 68.70%
#
# ######################################################################
# Knowledge Distillation runs with the copy of the student model:
# Epoch 1/10, Training Loss: nan
# Epoch 1/10, Validation Loss: 1.3491
# Epoch 2/10, Training Loss: nan
# Epoch 2/10, Validation Loss: 1.1691
# Epoch 3/10, Training Loss: nan
# Epoch 3/10, Validation Loss: 1.1147
# Epoch 4/10, Training Loss: nan
# Epoch 4/10, Validation Loss: 1.1400
# Epoch 5/10, Training Loss: nan
# Epoch 5/10, Validation Loss: 1.0848
# Epoch 6/10, Training Loss: nan
# Epoch 6/10, Validation Loss: 1.0542
# Epoch 7/10, Training Loss: nan
# Epoch 7/10, Validation Loss: 1.0401
# Epoch 8/10, Training Loss: nan
# Epoch 8/10, Validation Loss: 0.9882
# Epoch 9/10, Training Loss: nan
# Epoch 9/10, Validation Loss: 1.0056
# Epoch 10/10, Training Loss: nan
# Epoch 10/10, Validation Loss: 1.0134
# -----------------------------------------
# Student accuracy with CE + KD:
# Accuracy: 68.77%
# Precision: 0.70
# Recall: 0.69
# F1 Score: 0.69
# Model saved as teacher_model_cf10.pth, student_model_cf10.pth and student_model_KD_cf10.pth

# %% [markdown]
# Knowledge distillation run
# --------------------------

# %%
test_accuracy_light_ce = test_light_ce[1]["accuracy"] * 100
test_accuracy_light_ce_and_kd = test_light_ce_and_kd[1]["accuracy"] * 100

plt.suptitle("Training and Validation Loss of Student model", fontsize=16)

# Visualize the loss scores of student model - ce
plt.figure(figsize=(12, 10))
plt.subplot(1, 2, 1)
plt.plot(range(1, 11), train_light_ce[0], label="Train Loss")
plt.plot(range(1, 11), train_light_ce[1], label="Validation Loss")
# plt.axhline(y=test_accuracy_light_ce, color='red', linestyle='--', label='Test Accuracy')
plt.legend(loc='upper right')
plt.title('with Cross-Entropy')

# Visualize the loss scores of student model - ce + kd
plt.subplot(1, 2, 2)
plt.plot(range(1, 11), train_light_ce_and_kd[0], label="Train Loss")
plt.plot(range(1, 11), train_light_ce_and_kd[1], label="Validation Loss")
# plt.axhline(y=test_accuracy_light_ce_and_kd, color='red', linestyle='--', label='Test Accuracy')
plt.legend(loc='upper right')
plt.title('with Knowledge Distillation')
plt.show()

# %%
# Generate the confusion matrix
cm = test_light_ce_and_kd[0]
# Visualize the confusion matrix
plt.figure(figsize=(8, 6))
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix of Student model with Knowledge Distillation")
plt.show()
