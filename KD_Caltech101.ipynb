# %% [markdown]
# Knowledge Distillation Tutorial
# ===============================
#
# ######################################################################

# %% [markdown]
# Enviroment Setup
# ----------

# %%
# !nvidia-smi
# Out:
# Tue Dec  3 18:53:46 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 566.14                 Driver Version: 566.14         CUDA Version: 12.7     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4060      WDDM  |   00000000:01:00.0  On |                  N/A |
# |  0%   46C    P8             N/A /  115W |    3783MiB /   8188MiB |     11%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A      1392    C+G   ...nzyj5cx40ttqa\iCloud\iCloudHome.exe      N/A      |
# |    0   N/A  N/A      2248    C+G   ...t.LockApp_cw5n1h2txyewy\LockApp.exe      N/A      |
# |    0   N/A  N/A      4040    C+G   ...on\131.0.2903.63\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A      7784    C+G   ..._m7qx9dzpwqaze\app\Twinkle Tray.exe      N/A      |
# |    0   N/A  N/A     10276    C+G   C:\Windows\System32\mmgaserver.exe          N/A      |
# |    0   N/A  N/A     10560    C+G   ...ekyb3d8bbwe\PhoneExperienceHost.exe      N/A      |
# |    0   N/A  N/A     11812    C+G   ...4.11.1\plugins\capture\ZaloCall.exe      N/A      |
# |    0   N/A  N/A     11996    C+G   ...GeForce Experience\NVIDIA Share.exe      N/A      |
# |    0   N/A  N/A     12404    C+G   ...Programs\Microsoft VS Code\Code.exe      N/A      |
# |    0   N/A  N/A     12584    C+G   ...5n1h2txyewy\ShellExperienceHost.exe      N/A      |
# |    0   N/A  N/A     12860    C+G   ...CBS_cw5n1h2txyewy\TextInputHost.exe      N/A      |
# |    0   N/A  N/A     13440    C+G   ...mpt_builder\LogiAiPromptBuilder.exe      N/A      |
# |    0   N/A  N/A     13660      C   ...rograms\Python\Python310\python.exe      N/A      |
# |    0   N/A  N/A     14424    C+G   ...werToys\PowerToys.PowerLauncher.exe      N/A      |
# |    0   N/A  N/A     14484    C+G   ...on\131.0.2903.63\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A     15092    C+G   ...UI3Apps\PowerToys.AdvancedPaste.exe      N/A      |
# |    0   N/A  N/A     18216    C+G   ...ys\WinUI3Apps\PowerToys.Peek.UI.exe      N/A      |
# |    0   N/A  N/A     19204    C+G   C:\Windows\explorer.exe                     N/A      |
# |    0   N/A  N/A     20252    C+G   ...siveControlPanel\SystemSettings.exe      N/A      |
# |    0   N/A  N/A     21984    C+G   ...werToys\PowerToys.ColorPickerUI.exe      N/A      |
# |    0   N/A  N/A     22112    C+G   ...\PowerToys\PowerToys.FancyZones.exe      N/A      |
# |    0   N/A  N/A     22340    C+G   ...al\Discord\app-1.0.9172\Discord.exe      N/A      |
# |    0   N/A  N/A     23304    C+G   ...2txyewy\StartMenuExperienceHost.exe      N/A      |
# |    0   N/A  N/A     23320    C+G   ...nt.CBS_cw5n1h2txyewy\SearchHost.exe      N/A      |
# |    0   N/A  N/A     23560    C+G   ...oogle\Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A     24308    C+G   ...on\131.0.2903.63\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A     25876      C   ...rograms\Python\Python310\python.exe      N/A      |
# |    0   N/A  N/A     27680    C+G   ...tionsPlus\logioptionsplus_agent.exe      N/A      |
# |    0   N/A  N/A     27756    C+G   ...s\System32\ApplicationFrameHost.exe      N/A      |
# |    0   N/A  N/A     30108    C+G   ...t Office\root\Office16\POWERPNT.EXE      N/A      |
# |    0   N/A  N/A     30168      C   ...rograms\Python\Python310\python.exe      N/A      |
# |    0   N/A  N/A     30708    C+G   ...804_x64__8wekyb3d8bbwe\ms-teams.exe      N/A      |
# |    0   N/A  N/A     30940    C+G   ...les\Microsoft OneDrive\OneDrive.exe      N/A      |
# |    0   N/A  N/A     32384    C+G   C:\Windows\System32\ShellHost.exe           N/A      |
# |    0   N/A  N/A     36252    C+G   ...7.0_x64__cv1g1gvanyjgm\WhatsApp.exe      N/A      |
# |    0   N/A  N/A     36888      C   ...rograms\Python\Python310\python.exe      N/A      |
# |    0   N/A  N/A     37992    C+G   ...oogle\Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A     38356    C+G   ...Programs\Zalo\Zalo-24.11.1\Zalo.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import random_split, DataLoader
import torchvision.transforms as transforms
import torchvision.datasets as datasets

import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay

import shutil
from tabulate import tabulate

# %%
# Print the current working directory
print(f"The notebook is located in: {os.getcwd()}")

# Check if GPU is available, and if not, use the CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
if torch.cuda.is_available(): # Should return True 
    print(f"Using GPU: {torch.cuda.get_device_name(0)}") # Should show your GPU name
else:
    print("Using CPU")
# Out:
# The notebook is located in: d:\Arcade Projects\Knowledge_Distillation_Testing
# Using GPU: NVIDIA GeForce RTX 4060

# %% [markdown]
# Caltech101 (101 classes)
# ------------
# split **9144** samples as **5552 (train)**, **1389 (validation)**, and **1736 (test)**.

# %%
# Transformations for data preprocessing
transform = transforms.Compose([
    transforms.Grayscale(num_output_channels=3),
    transforms.Resize((32,32)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# To download the dataset gdown is required.
# Loading the Caltech-101 dataset: (train set will later be split into train and val)
full_dataset = datasets.Caltech101(root='./data', download=True, transform=transform)
# Out:
# Files already downloaded and verified

# %%
# Split trainset into train, validation, testing datasets (60% train, 20% val, 20% test)
train_val_size = int(0.8 * len(full_dataset))
test_size = len(full_dataset) - train_val_size
train_valset, testset = random_split(full_dataset, [train_val_size, test_size])
train_size = int(0.8 * len(train_valset))
val_size= len(train_valset) - train_size
trainset, valset = random_split(train_valset, [train_size, val_size])

# DataLoaders for train, validation, and test datasets
train_loader = DataLoader(trainset, batch_size=32, shuffle=True, num_workers=2)
val_loader = DataLoader(valset, batch_size=32, shuffle=False, num_workers=2)
test_loader = DataLoader(testset, batch_size=32, shuffle=False, num_workers=2)

# Check if dataset loads correctly
print(f"Number of training samples: {len(trainset)}")
print(f"Number of validation samples: {len(valset)}")
print(f"Number of testing samples: {len(testset)}")
# Out:
# Number of training samples: 5552
# Number of validation samples: 1389
# Number of testing samples: 1736

# %% [markdown]
# Defining model classes and utility functions
# ----------

# %%
# Deeper neural network class to be used as teacher:
class DeepNN(nn.Module):
    def __init__(self, num_classes=10):
        super(DeepNN, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 128, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(128, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(64, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(64, 32, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
        )
        self.classifier = nn.Sequential(
            nn.Linear(2048, 512),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(512, num_classes)
        )

    def forward(self, x):
        x = self.features(x)
        x = torch.flatten(x, 1)
        x = self.classifier(x)
        return x
    
# Lightweight neural network class to be used as student:
class LightNN(nn.Module):
    def __init__(self, num_classes=10):
        super(LightNN, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 16, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(16, 16, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
        )
        self.classifier = nn.Sequential(
            nn.Linear(1024, 256),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(256, num_classes)
        )

    def forward(self, x):
        x = self.features(x)
        x = torch.flatten(x, 1)
        x = self.classifier(x)
        return x

# %%
def train(model, train_loader, val_loader, epochs, learning_rate, device):
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)

    model.train()

    for epoch in range(epochs):
        running_loss = 0.0
        for inputs, labels in train_loader:
            # inputs: A collection of batch_size images
            # labels: A vector of dimensionality batch_size with integers denoting class of each image
            inputs, labels = inputs.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(inputs)

            # outputs: Output of the network for the collection of images. A tensor of dimensionality batch_size x num_classes
            # labels: The actual labels of the images. Vector of dimensionality batch_size
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        print(f"Epoch {epoch+1}/{epochs}, Training Loss: {running_loss / len(train_loader)}")

        # Validation Step
        val_loss = 0.0
        with torch.no_grad():  # Disable gradient computation for validation
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                val_loss += loss.item() 

        avg_val_loss = val_loss / len(val_loader)  # Average validation loss
        print(f"Epoch {epoch+1}/{epochs}, Validation Loss: {avg_val_loss:.4f}")    

def test(model, test_loader, device):
    model.to(device)
    model.eval()

    all_labels = []
    all_predictions = []

    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)

            outputs = model(inputs)
            _, predicted = torch.max(outputs.data, 1)
	
            # Collect predictions and true labels
            all_predictions.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    # Calculate metrics using sklearn
    cm = confusion_matrix(all_labels, all_predictions)
    report = classification_report(all_labels, all_predictions, output_dict=True, zero_division=0)

    return cm, report

# %% [markdown]
# Cross-entropy runs
# -----------------

# %%
torch.manual_seed(42)
nn_deep = DeepNN(num_classes=101).to(device)
train(nn_deep, train_loader, val_loader, epochs=10, learning_rate=0.001, device=device)
test_deep = test(nn_deep, test_loader, device)
accuracy_deep = test_deep[1]["accuracy"] * 100
print(f"Teacher Accuracy: {accuracy_deep:.2f}%")
# Out:
# Epoch 1/10, Training Loss: 3.5754719862992737
# Epoch 1/10, Validation Loss: 3.0630
# Epoch 2/10, Training Loss: 2.4852581654471915
# Epoch 2/10, Validation Loss: 2.4735
# Epoch 3/10, Training Loss: 1.7566759524674251
# Epoch 3/10, Validation Loss: 2.2654
# Epoch 4/10, Training Loss: 1.0936897138411972
# Epoch 4/10, Validation Loss: 2.4074
# Epoch 5/10, Training Loss: 0.6080663038481926
# Epoch 5/10, Validation Loss: 3.0013
# Epoch 6/10, Training Loss: 0.3151315559857878
# Epoch 6/10, Validation Loss: 3.5972
# Epoch 7/10, Training Loss: 0.2287222609437745
# Epoch 7/10, Validation Loss: 3.8536
# Epoch 8/10, Training Loss: 0.14867203096034884
# Epoch 8/10, Validation Loss: 4.1441
# Epoch 9/10, Training Loss: 0.09255619103760705
# Epoch 9/10, Validation Loss: 4.7022
# Epoch 10/10, Training Loss: 0.14489902603311527
# Epoch 10/10, Validation Loss: 4.3275
# Teacher Accuracy: 53.63%

# %%
# Instantiate the lightweight network:
torch.manual_seed(42)
nn_light = LightNN(num_classes=101).to(device)

# Re-instantiate the lightweight network:
torch.manual_seed(42)
new_nn_light = LightNN(num_classes=101).to(device)

# %%
# Print the norm of the first layer of the initial lightweight model
print("Norm of 1st layer of nn_light:", torch.norm(nn_light.features[0].weight).item())
# Print the norm of the first layer of the new lightweight model
print("Norm of 1st layer of new_nn_light:", torch.norm(new_nn_light.features[0].weight).item())
# Out:
# Norm of 1st layer of nn_light: 2.327361822128296
# Norm of 1st layer of new_nn_light: 2.327361822128296

# %%
# Print the total number of parameters in each model:
total_params_deep = "{:,}".format(sum(p.numel() for p in nn_deep.parameters()))
print(f"DeepNN parameters: {total_params_deep}")
total_params_light = "{:,}".format(sum(p.numel() for p in nn_light.parameters()))
print(f"LightNN parameters: {total_params_light}")
# Out:
# DeepNN parameters: 1,233,669
# LightNN parameters: 291,125

# %%
train(nn_light, train_loader, val_loader, epochs=10, learning_rate=0.001, device=device)
test_light_ce = test(nn_light, test_loader, device)
accuracy_light_ce = test_light_ce[1]["accuracy"] * 100
print(f"Teacher Accuracy: {accuracy_light_ce:.2f}%")
# Out:
# Epoch 1/10, Training Loss: 3.537331463276655
# Epoch 1/10, Validation Loss: 3.0316
# Epoch 2/10, Training Loss: 2.5565169946900728
# Epoch 2/10, Validation Loss: 2.5335
# Epoch 3/10, Training Loss: 2.0182159001799835
# Epoch 3/10, Validation Loss: 2.3194
# Epoch 4/10, Training Loss: 1.6142079751381928
# Epoch 4/10, Validation Loss: 2.1824
# Epoch 5/10, Training Loss: 1.2894254792695758
# Epoch 5/10, Validation Loss: 2.2566
# Epoch 6/10, Training Loss: 1.0475658243415
# Epoch 6/10, Validation Loss: 2.3593
# Epoch 7/10, Training Loss: 0.8117269544765867
# Epoch 7/10, Validation Loss: 2.4530
# Epoch 8/10, Training Loss: 0.6242165136440047
# Epoch 8/10, Validation Loss: 2.6327
# Epoch 9/10, Training Loss: 0.48506168644318637
# Epoch 9/10, Validation Loss: 2.7690
# Epoch 10/10, Training Loss: 0.36770179974793016
# Epoch 10/10, Validation Loss: 3.0317
# Teacher Accuracy: 55.65%

# %% [markdown]
# Knowledge distillation run
# --------------------------

# %%
def train_knowledge_distillation(teacher, student, train_loader, val_loader, epochs, learning_rate, T, soft_target_loss_weight, ce_loss_weight, device):
    ce_loss = nn.CrossEntropyLoss()
    optimizer = optim.Adam(student.parameters(), lr=learning_rate)

    teacher.eval()  # Teacher set to evaluation mode
    student.train() # Student to train mode

    for epoch in range(epochs):
        running_loss = 0.0
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)

            optimizer.zero_grad()

            # Forward pass with the teacher model - do not save gradients here as we do not change the teacher's weights
            with torch.no_grad():
                teacher_logits = teacher(inputs)

            # Forward pass with the student model
            student_logits = student(inputs)

            #Soften the student logits by applying softmax first and log() second
            soft_targets = nn.functional.softmax(teacher_logits / T, dim=-1)
            soft_prob = nn.functional.log_softmax(student_logits / T, dim=-1)

            # Calculate the soft targets loss. Scaled by T**2 as suggested by the authors of the paper "Distilling the knowledge in a neural network"
            soft_targets_loss = torch.sum(soft_targets * (soft_targets.log() - soft_prob)) / soft_prob.size()[0] * (T**2)

            # Calculate the true label loss
            label_loss = ce_loss(student_logits, labels)

            # Weighted sum of the two losses
            loss = soft_target_loss_weight * soft_targets_loss + ce_loss_weight * label_loss

            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        print(f"Epoch {epoch+1}/{epochs}, Training Loss: {running_loss / len(train_loader)}")

        # Validation Step
        val_loss = 0.0
        with torch.no_grad():  # Disable gradient computation for validation
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = student(inputs)
                loss = ce_loss(outputs, labels)
                val_loss += loss.item() 

        avg_val_loss = val_loss / len(val_loader)  # Average validation loss
        print(f"Epoch {epoch+1}/{epochs}, Validation Loss: {avg_val_loss:.4f}")   

# Apply ``train_knowledge_distillation`` with a temperature of 2. Arbitrarily set the weights to 0.75 for CE and 0.25 for distillation loss.
train_knowledge_distillation(teacher=nn_deep, student=new_nn_light, train_loader=train_loader, val_loader=val_loader, epochs=10, learning_rate=0.001, T=2, soft_target_loss_weight=0.25, ce_loss_weight=0.75, device=device)
test_light_ce_and_kd = test(new_nn_light, test_loader, device)
accuracy_light_ce_and_kd = test_light_ce_and_kd[1]["accuracy"] * 100
precision_light_ce_and_kd = test_light_ce_and_kd[1]["weighted avg"]["precision"]
recall_light_ce_and_kd = test_light_ce_and_kd[1]["weighted avg"]["recall"]
f1_light_ce_and_kd = test_light_ce_and_kd[1]["weighted avg"]["f1-score"]

# Compare the student test accuracy with and without the teacher, after distillation
print("-----------------------------------------")
print(f"Teacher accuracy: {accuracy_deep:.2f}%")
print(f"Student accuracy without teacher: {accuracy_light_ce:.2f}%")

print("-----------------------------------------")
print(f"Student accuracy with CE + KD:")
print(f"Accuracy: {accuracy_light_ce_and_kd:.2f}%")
# Print other value metrics:
print(f"Precision: {precision_light_ce_and_kd:.2f}")
print(f"Recall: {recall_light_ce_and_kd:.2f}")
print(f"F1 Score: {f1_light_ce_and_kd:.2f}")
# Out:
# Epoch 1/10, Training Loss: 6.084973751813516
# Epoch 1/10, Validation Loss: 3.1624
# Epoch 2/10, Training Loss: 4.4827868869934955
# Epoch 2/10, Validation Loss: 2.7035
# Epoch 3/10, Training Loss: 3.6099030217905153
# Epoch 3/10, Validation Loss: 2.5478
# Epoch 4/10, Training Loss: 2.9232590678094446
# Epoch 4/10, Validation Loss: 2.4523
# Epoch 5/10, Training Loss: 2.3881284409555894
# Epoch 5/10, Validation Loss: 2.6186
# Epoch 6/10, Training Loss: 1.9458355790582196
# Epoch 6/10, Validation Loss: 2.7124
# Epoch 7/10, Training Loss: 1.5374176851634322
# Epoch 7/10, Validation Loss: 3.0989
# Epoch 8/10, Training Loss: 1.2507553001244862
# Epoch 8/10, Validation Loss: 3.1957
# Epoch 9/10, Training Loss: 1.0129276209179012
# Epoch 9/10, Validation Loss: 3.4496
# Epoch 10/10, Training Loss: 0.8180185513592314
# Epoch 10/10, Validation Loss: 3.5989
# -----------------------------------------
# Teacher accuracy: 53.63%
# Student accuracy without teacher: 55.65%
# -----------------------------------------
# Student accuracy with CE + KD:
# Accuracy: 56.74%
# Precision: 0.57
# Recall: 0.57
# F1 Score: 0.56

# %%
# Generate the confusion matrix
cm = test_light_ce_and_kd[0]

# Visualize the confusion matrix
fig, ax = plt.subplots()
fig.set_size_inches(24, 24)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues, ax=ax, colorbar=False)
plt.title("Confusion Matrix")
plt.show()
