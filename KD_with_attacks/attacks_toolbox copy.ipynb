# %%
import numpy as np
import torch
import torch.nn as nn
import art.attacks.evasion as toolbox
from art.estimators.classification import PyTorchClassifier
# from kd_export import LightNN
from mvtec import test_dataset
# Out:
# Organizing dataset...
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[4], line 7
#       5 from art.estimators.classification import PyTorchClassifier
#       6 # from kd_export import LightNN
# ----> 7 from mvtec import test_dataset
#
# File d:\Arcade Projects\Knowledge_Distillation_Testing\KD_Export\mvtec.py:58
#      56     for img_file in os.listdir(train_good_path):
#      57         if img_file.lower().endswith(('.png', '.jpg', '.jpeg')):
# ---> 58             shutil.copyfile(
#      59                 os.path.join(train_good_path, img_file),
#      60                 os.path.join(train_tool_output, img_file)
#      61             )
#      62             train_count += 1
#      64 if os.path.exists(test_good_path):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\shutil.py:256, in copyfile(src, dst, follow_symlinks)
#     254 with open(src, 'rb') as fsrc:
#     255     try:
# --> 256         with open(dst, 'wb') as fdst:
#     257             # macOS
#     258             if _HAS_FCOPYFILE:
#     259                 try:
#
# PermissionError: [Errno 13] Permission denied: './mvtec_dataset\\organized_train\\bottle\\000.png'

# %%
class LightNN(nn.Module):
    def __init__(self, num_classes=10):
        super(LightNN, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 16, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(16, 16, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
        )
        self.classifier = nn.Sequential(
            nn.Linear(16 * 56 * 56, 256),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(256, num_classes)
        )

    def forward(self, x):
        x = self.features(x)
        x = torch.flatten(x, 1)
        x = self.classifier(x)
        return x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 class LightNN(nn.Module):
#       2     def __init__(self, num_classes=10):
#       3         super(LightNN, self).__init__()
#
# NameError: name 'nn' is not defined

# %%
print("Check current device: ")
# Check if GPU is available, and if not, use the CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
if torch.cuda.is_available(): # Should return True 
    print(f"Using GPU: {torch.cuda.get_device_name(0)}") # Should show your GPU name
else:
    print("Using CPU")
# Out:
# Check current device:
# Using GPU: NVIDIA GeForce RTX 4060

# %%
epsilons = [0, .05, .1, .15, .2, .25, .3, .35, .4, .45, .5, .55, .6, .65, .7, .75, .8, .85, .9, .95]
pretrained_model = "student_model.pth"
pretrained_model_KD = "student_model_KD.pth"
use_cuda=True
# Set random seed for reproducibility
torch.manual_seed(42)

# %%
# Initialize the network
torch.manual_seed(42)
model = LightNN(num_classes=15).to(device)
torch.manual_seed(42)
model_KD = LightNN(num_classes=15).to(device)


# Load the pretrained model
model.load_state_dict(torch.load(pretrained_model, map_location=device, weights_only=True))
model_KD.load_state_dict(torch.load(pretrained_model_KD, map_location=device, weights_only=True))

# Set the model in evaluation mode. In this case this is for the Dropout layers
model.eval()
model_KD.eval()
# Out:
# LightNN(
#   (features): Sequential(
#     (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU()
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=50176, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.1, inplace=False)
#     (3): Linear(in_features=256, out_features=15, bias=True)
#   )
# )

# %%
# Define loss function and optimizer
loss_fn = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# Wrap the model with PyTorchClassifier
classifier = PyTorchClassifier(
    model=model,
    clip_values=(0, 1),  # Input values range, e.g., for normalized images
    loss=loss_fn,
    optimizer=optimizer,
    input_shape=(3, 224, 224),  # Adjust to your input shape
    nb_classes=15              # Number of output classes
)

# %%
x_test = np.array([data[0].numpy() for data in test_dataset])
y_test = np.array([data[1] for data in test_dataset])

# %%
# Create FGSM attack
attack = toolbox.FastGradientMethod(estimator=classifier, eps=0.1)

# Generate adversarial examples
x_test_adv_fgsm = attack.generate(x=x_test)

# Evaluate accuracy on adversarial examples
predictions = classifier.predict(x_test_adv_fgsm)
accuracy = np.sum(np.argmax(predictions, axis=1) == y_test) / len(y_test)
print(f"Accuracy on FSGM attack: {accuracy * 100:.2f}%")
# Out:
# Accuracy on FSGM attack: 88.22%

# %%
# Create PGD attack
pgd_attack = toolbox.ProjectedGradientDescent(estimator=classifier, eps=0.1, eps_step=0.01, max_iter=40)

# Generate adversarial examples
x_test_adv_pgd = pgd_attack.generate(x=x_test)

# Evaluate accuracy on adversarial examples
predictions = classifier.predict(x_test_adv_pgd)
accuracy = np.sum(np.argmax(predictions, axis=1) == y_test) / len(y_test)
print(f"Accuracy on PGD attack: {accuracy * 100:.2f}%")
# Out:
# Accuracy on PGD attack: 76.66%

# %%
# Create C&W attack
cw2_attack = toolbox.CarliniL2Method(classifier=classifier, confidence=0.0, max_iter=40, learning_rate=0.01)

# Generate adversarial examples
x_test_adv_cw2 = cw2_attack.generate(x=x_test)

# Evaluate accuracy on adversarial examples
predictions = classifier.predict(x_test_adv_cw2)
accuracy = np.sum(np.argmax(predictions, axis=1) == y_test) / len(y_test)
print(f"Accuracy on CW2 attack: {accuracy * 100:.2f}%")
# Out:
# C&W L_2:   0%|          | 1/467 [00:16<2:10:48, 16.84s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 5
#       2 cw2_attack = toolbox.CarliniL2Method(classifier=classifier, confidence=0.0, max_iter=40, learning_rate=0.01)
#       4 # Generate adversarial examples
# ----> 5 x_test_adv_cw2 = cw2_attack.generate(x=x_test)
#       7 # Evaluate accuracy on adversarial examples
#       8 predictions = classifier.predict(x_test_adv_cw2)
#
# File d:\Arcade Projects\Knowledge_Distillation_Testing\.venv\lib\site-packages\art\attacks\evasion\carlini.py:376, in CarliniL2Method.generate(self, x, y, **kwargs)
#     374 new_x_adv_batch_tanh = x_adv1 + lr_mult * perturbation_tanh[do_halving]
#     375 new_x_adv_batch = tanh_to_original(new_x_adv_batch_tanh, clip_min, clip_max)
# --> 376 _, l2dist[active_and_do_halving], loss[active_and_do_halving] = self._loss(
#     377     x_batch[active_and_do_halving],
#     378     new_x_adv_batch,
#     379     y_batch[active_and_do_halving],
#     380     c_current[active_and_do_halving],
#     381 )
#     383 logger.debug("New Average Loss: %f", np.mean(loss))
#     384 logger.debug("New Average L2Dist: %f", np.mean(l2dist))
#
# File d:\Arcade Projects\Knowledge_Distillation_Testing\.venv\lib\site-packages\art\attacks\evasion\carlini.py:151, in CarliniL2Method._loss(self, x, x_adv, target, c_weight)
#     141 """
#     142 Compute the objective function value.
#     143
#    (...)
#     148 :return: A tuple holding the current logits, l2 distance and overall loss.
#     149 """
#     150 l2dist = np.sum(np.square(x - x_adv).reshape(x.shape[0], -1), axis=1)
# --> 151 z_predicted = self.estimator.predict(
#     152     np.array(x_adv, dtype=ART_NUMPY_DTYPE),
#     153     logits=True,
#     154     batch_size=self.batch_size,
#     155 )
#     156 z_target = np.sum(z_predicted * target, axis=1)
#     157 z_other = np.max(
#     158     z_predicted * (1 - target) + (np.min(z_predicted, axis=1) - 1)[:, np.newaxis] * target,
#     159     axis=1,
#     160 )
#
# File d:\Arcade Projects\Knowledge_Distillation_Testing\.venv\lib\site-packages\art\estimators\classification\classifier.py:75, in InputFilter.__init__.<locals>.make_replacement.<locals>.replacement_function(self, *args, **kwargs)
#      73 if len(args) > 0:
#      74     args = tuple(lst)
# ---> 75 return fdict[func_name](self, *args, **kwargs)
#
# File d:\Arcade Projects\Knowledge_Distillation_Testing\.venv\lib\site-packages\art\estimators\classification\pytorch.py:315, in PyTorchClassifier.predict(self, x, batch_size, training_mode, **kwargs)
#     312 self._model.train(mode=training_mode)
#     314 # Apply preprocessing
# --> 315 x_preprocessed, _ = self._apply_preprocessing(x, y=None, fit=False)
#     317 # Create dataloader
#     318 x_tensor = torch.from_numpy(x_preprocessed)
#
# File d:\Arcade Projects\Knowledge_Distillation_Testing\.venv\lib\site-packages\art\estimators\pytorch.py:190, in PyTorchEstimator._apply_preprocessing(self, x, y, fit, no_grad)
#     188 if no_grad:
#     189     with torch.no_grad():
# --> 190         x, y = chain_processes(x, y)
#     191 else:
#     192     x, y = chain_processes(x, y)
#
# File d:\Arcade Projects\Knowledge_Distillation_Testing\.venv\lib\site-packages\art\estimators\pytorch.py:185, in PyTorchEstimator._apply_preprocessing.<locals>.chain_processes(x, y)
#     183     else:
#     184         if preprocess.apply_predict:
# --> 185             x, y = preprocess.forward(x, y)
#     186 return x, y
#
# File d:\Arcade Projects\Knowledge_Distillation_Testing\.venv\lib\site-packages\art\preprocessing\standardisation_mean_std\pytorch.py:90, in StandardisationMeanStdPyTorch.forward(self, x, y)
#      87     self._broadcastable_mean, self._broadcastable_std = broadcastable_mean_std(x, self.mean, self.std)
#      89 x_norm = x - torch.tensor(self._broadcastable_mean, device=self._device, dtype=torch.float32)
# ---> 90 x_norm = x_norm / torch.tensor(self._broadcastable_std, device=self._device, dtype=torch.float32)
#      92 return x_norm, y
#
# KeyboardInterrupt:

# %%
# Create Universal Perturbations attack
up_attack = toolbox.UniversalPerturbation(classifier=classifier, attacker="deepfool",
                                        #   delta=0.2,
                                          max_iter=10,
                                          eps=0.1,
                                        #   batch_size=32,
                                        #   verbose=True
                                        )

# Generate adversarial examples
x_test_adv_up = up_attack.generate(x=x_test)

# Evaluate accuracy on adversarial examples
predictions = classifier.predict(x_test_adv_up)
accuracy = np.sum(np.argmax(predictions, axis=1) == y_test) / len(y_test)
print(f"Accuracy on UP attack: {accuracy * 100:.2f}%")
# Out:
# DeepFool: 100%|██████████| 1/1 [00:01<00:00,  1.40s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  2.85it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  2.91it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.28s/it]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 15.63it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.22s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  3.59it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.15s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  5.53it/s]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 17.82it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.15s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.09s/it]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 17.84it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  3.61it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.12s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.22s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.11s/it]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 18.36it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.15s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.11s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.17s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  3.60it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.21s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.24s/it]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 16.90it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  2.01it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.24s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.30s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  3.16it/s]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 17.24it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.21s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.21s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  2.92it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  3.15it/s]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 17.40it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.20s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.15s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  1.25it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  4.11it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  2.48it/s]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 13.51it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.16s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.18s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  3.70it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:01<00:00,  1.65s/it]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 18.11it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.18s/it]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 17.82it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.18s/it]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 16.82it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.24s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  3.67it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.12s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.02s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  2.88it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:02<00:00,  2.99s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.08s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.07s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:02<00:00,  2.98s/it]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 19.75it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.02s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:02<00:00,  2.99s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:02<00:00,  2.98s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  3.71it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.06s/it]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 18.20it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  3.24it/s]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 18.17it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  3.51it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  2.56it/s]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 19.12it/s]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 18.18it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:01<00:00,  1.38s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  1.92it/s]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 18.81it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  2.74it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.08s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.05s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  3.32it/s]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 17.37it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  2.98it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.12s/it]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 17.54it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.15s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.11s/it]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 18.13it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.12s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  2.68it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.16s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.14s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.16s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.18s/it]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 17.60it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  3.65it/s]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 18.87it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.13s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  3.06it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  2.03it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  3.59it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.10s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  2.66it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.11s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  2.62it/s]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 19.15it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.12s/it]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 19.42it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  3.33it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.06s/it]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 17.53it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.11s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.02s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  2.75it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.13s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  3.51it/s]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 18.81it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.02s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.11s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:01<00:00,  1.31s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.06s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  3.23it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.09s/it]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 19.05it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.13s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.03s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:01<00:00,  1.67s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.09s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.09s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  2.79it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  1.35it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.15s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  3.62it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.15s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.13s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.12s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  3.11it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.10s/it]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 18.01it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  2.23it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.14s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.12s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.12s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.23s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.22s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  3.68it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:01<00:00,  1.36s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.02s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.06s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  1.47it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  1.17it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  3.35it/s]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 17.01it/s]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 17.72it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  2.74it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:01<00:00,  1.20s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  2.41it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.21s/it]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 19.14it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.20s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  2.10it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  2.13it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.76s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.15s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  2.54it/s]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 14.49it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.30s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.05s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.54s/it]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 17.39it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.19s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.09s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.10s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.03s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  1.10it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.15s/it]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 18.18it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.04s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  2.25it/s]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 19.03it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:01<00:00,  1.22s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:01<00:00,  1.52s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.04s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.13s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  2.55it/s]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 18.43it/s]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 18.61it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.06s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.19s/it]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 14.12it/s]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 17.27it/s]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 16.47it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  2.71it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.41s/it]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 18.87it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.09s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.15s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.03s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  1.58it/s]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 18.62it/s]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 19.19it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  3.55it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.03s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.04s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.05s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  2.20it/s]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 19.31it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.03s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.05s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.04s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  2.44it/s]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 18.30it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.04s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  6.62it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  2.63it/s]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 18.51it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.18s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.08s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  4.85it/s]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 14.36it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.11s/it]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 17.98it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.08s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.05s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  3.45it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  5.78it/s]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 18.59it/s]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 15.87it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  1.24it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.08s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  2.84it/s]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 17.92it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.06s/it]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 17.85it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.04s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.07s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.20s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  3.81it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.08s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  3.21it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.05s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:01<00:00,  1.30s/it]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 16.59it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.08s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.14s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.07s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.02s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  3.11it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.06s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.05s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.03s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  2.85it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.06s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.09s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  3.42it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.03s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.05s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.06s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.08s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:01<00:00,  1.01s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.06s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  2.84it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:01<00:00,  1.36s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  2.82it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.07s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  3.95it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.04s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.08s/it]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 18.17it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.03s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.04s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.07s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.10s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  3.89it/s]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 16.03it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.09s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.05s/it]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 16.91it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.06s/it]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 18.90it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.03s/it]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 18.24it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.17s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.21s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.08s/it]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 18.30it/s]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 17.67it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.07s/it]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 18.68it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  3.25it/s]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 17.85it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  1.88it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.10s/it]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 18.83it/s]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 18.99it/s]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 19.32it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  2.18it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.04s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.17s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.13s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.10s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.08s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.15s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  3.32it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.11s/it]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 17.83it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.11s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  3.35it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.07s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.15s/it]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 16.97it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.22s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00,  2.41it/s]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 18.18it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.14s/it]
#
#
# DeepFool: 100%|██████████| 1/1 [00:00<00:00, 16.92it/s]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.10s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.08s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.18s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.25s/it]
#
#
#
#
# DeepFool: 100%|██████████| 1/1 [00:03<00:00,  3.16s/it]
